# %% [markdown]
# # Fast Oriented Text Spotting Final Model notebook

# %%
# importing the libraries
import glob
import csv
import cv2
import time
import os
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
import matplotlib.patches as Patches
from shapely.geometry import Polygon
import random
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
import threading
import shutil
import pandas as pd
import os
import math
import csv
import cv2
import time
import shutil
import os
import numpy as np
import scipy.optimize
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.patches as Patches
from shapely.geometry import Polygon
import random
import tensorflow as tf
from tqdm import tqdm
import multiprocessing
import scipy.io as sio
try:
    import queue
except ImportError:
    import Queue as queue

# %%
# The references for the below code is taken from
# https://github.com/jiangxiluning/FOTS.PyTorch/tree/master/FOTS
# https://github.com/Pay20Y/FOTS_TF
# https://github.com/Masao-Taketani/FOTS_OCR
# https://github.com/sugam95/FOTS

# %% [markdown]
# # Let's load the functions  for generating  bounding boxes around the text

# %%
#All the functions in this block are used to generating  bounding boxes around the text

# This Function is used to calculate AREA of polygon
def polygon_area(poly):
    '''
    compute area of a polygon
    '''
    edge = [
        (poly[1][0] - poly[0][0]) * (poly[1][1] + poly[0][1]),
        (poly[2][0] - poly[1][0]) * (poly[2][1] + poly[1][1]),
        (poly[3][0] - poly[2][0]) * (poly[3][1] + poly[2][1]),
        (poly[0][0] - poly[3][0]) * (poly[0][1] + poly[3][1])
    ]
    return np.sum(edge)/2.

# This function is used to discard invalid polygons and check direction of them

def check_and_validate_polys(polys, tags, xxx_todo_changeme):


    def is_polygon(poly):
        for i in range(3):
            p0 = poly[i]

        p1 = poly[(i + 1) % 4]
        p2 = poly[(i + 2) % 4]
    
        if p0[0] == p1[0] and p1[1] == p0[1]:
            return False
        if p0[0] == p2[0] and p2[1] == p0[1]:
            return False
        if p1[0] == p2[0] and p1[1] == p2[1]:
            return False
    
        if p0[0] == p1[0]:
            if p1[0] == p2[0]:
                return False
        else:
            if p1[0] != p2[0]:
                k1 = (p1[1] - p0[1]) / (p1[0] - p0[0])
                k2 = (p2[1] - p1[1]) / (p2[0] - p1[0])
                if abs(k1 - k2) < 1e-6:
                    return False
                else:
                    if p1[1] == p2[1]:
                        return False
        
        return True

    (h, w) = xxx_todo_changeme
    if polys.shape[0] == 0:
        return polys
    polys[:, :, 0] = np.clip(polys[:, :, 0], 0, w - 1)
    polys[:, :, 1] = np.clip(polys[:, :, 1], 0, h - 1)

    validated_polys = []
    validated_tags = []
    for poly, tag in zip(polys, tags):
        p_area = polygon_area(poly)

        # memory error after hitting not a polygon !!!
        if is_polygon(poly) is False:
            #print("not a polygon: ", poly)
            continue

        if abs(p_area) < 1:
            # print poly
            #print('invalid poly')
            continue
        if p_area > 0:
            #print('poly in wrong direction')
            poly = poly[(0, 3, 2, 1), :]
        validated_polys.append(poly)
        validated_tags.append(tag)
    return np.array(validated_polys), np.array(validated_tags)    
    
    
#This function is implementation of Polygon Shrinkage Algorithm 
def shrink_poly(poly, r):
    '''
    fit a poly inside the origin poly
    used for generate the score map
    '''
    # shrink ratio
    R = 0.3
    # find the longer pair
    if np.linalg.norm(poly[0] - poly[1]) + np.linalg.norm(poly[2] - poly[3]) > \
                    np.linalg.norm(poly[0] - poly[3]) + np.linalg.norm(poly[1] - poly[2]):
        # first move (p0, p1), (p2, p3), then (p0, p3), (p1, p2)
        ## p0, p1
        theta = np.arctan2((poly[1][1] - poly[0][1]), (poly[1][0] - poly[0][0]))
        poly[0][0] += R * r[0] * np.cos(theta)
        poly[0][1] += R * r[0] * np.sin(theta)
        poly[1][0] -= R * r[1] * np.cos(theta)
        poly[1][1] -= R * r[1] * np.sin(theta)
        ## p2, p3
        theta = np.arctan2((poly[2][1] - poly[3][1]), (poly[2][0] - poly[3][0]))
        poly[3][0] += R * r[3] * np.cos(theta)
        poly[3][1] += R * r[3] * np.sin(theta)
        poly[2][0] -= R * r[2] * np.cos(theta)
        poly[2][1] -= R * r[2] * np.sin(theta)
        ## p0, p3
        theta = np.arctan2((poly[3][0] - poly[0][0]), (poly[3][1] - poly[0][1]))
        poly[0][0] += R * r[0] * np.sin(theta)
        poly[0][1] += R * r[0] * np.cos(theta)
        poly[3][0] -= R * r[3] * np.sin(theta)
        poly[3][1] -= R * r[3] * np.cos(theta)
        ## p1, p2
        theta = np.arctan2((poly[2][0] - poly[1][0]), (poly[2][1] - poly[1][1]))
        poly[1][0] += R * r[1] * np.sin(theta)
        poly[1][1] += R * r[1] * np.cos(theta)
        poly[2][0] -= R * r[2] * np.sin(theta)
        poly[2][1] -= R * r[2] * np.cos(theta)
    else:
        ## p0, p3
        # print poly
        theta = np.arctan2((poly[3][0] - poly[0][0]), (poly[3][1] - poly[0][1]))
        poly[0][0] += R * r[0] * np.sin(theta)
        poly[0][1] += R * r[0] * np.cos(theta)
        poly[3][0] -= R * r[3] * np.sin(theta)
        poly[3][1] -= R * r[3] * np.cos(theta)
        ## p1, p2
        theta = np.arctan2((poly[2][0] - poly[1][0]), (poly[2][1] - poly[1][1]))
        poly[1][0] += R * r[1] * np.sin(theta)
        poly[1][1] += R * r[1] * np.cos(theta)
        poly[2][0] -= R * r[2] * np.sin(theta)
        poly[2][1] -= R * r[2] * np.cos(theta)
        ## p0, p1
        theta = np.arctan2((poly[1][1] - poly[0][1]), (poly[1][0] - poly[0][0]))
        poly[0][0] += R * r[0] * np.cos(theta)
        poly[0][1] += R * r[0] * np.sin(theta)
        poly[1][0] -= R * r[1] * np.cos(theta)
        poly[1][1] -= R * r[1] * np.sin(theta)
        ## p2, p3
        theta = np.arctan2((poly[2][1] - poly[3][1]), (poly[2][0] - poly[3][0]))
        poly[3][0] += R * r[3] * np.cos(theta)
        poly[3][1] += R * r[3] * np.sin(theta)
        poly[2][0] -= R * r[2] * np.cos(theta)
        poly[2][1] -= R * r[2] * np.sin(theta)
    return poly



#Compute distance between p1-p2 and p3
def point_dist_to_line(p1, p2, p3):
    '''compute the distance from p3 to p1-p2'''
    return np.linalg.norm(np.cross(p2 - p1, p1 - p3)) / np.linalg.norm(p2 - p1)

#Find equation of line using two 2D points p1 and p2
def fit_line(p1, p2):
    '''fit a line ax+by+c = 0'''
    if p1[0] == p1[1]:
        return [1., 0., -p1[0]]
    else:
        [k, b] = np.polyfit(p1, p2, deg=1)
        return [k, -1., b]

#Find Intersection poitn of 2 lines
def line_cross_point(line1, line2):
    '''line1 0= ax+by+c, compute the cross point of line1 and line2'''
    if line1[0] != 0 and line1[0] == line2[0]:
        print('Cross point does not exist')
        return None
    if line1[0] == 0 and line2[0] == 0:
        print('Cross point does not exist')
        return None
    if line1[1] == 0:
        x = -line1[2]
        y = line2[0] * x + line2[2]
    elif line2[1] == 0:
        x = -line2[2]
        y = line1[0] * x + line1[2]
    else:
        k1, _, b1 = line1
        k2, _, b2 = line2
        x = -(b1-b2)/(k1-k2)
        y = k1*x + b1
    return np.array([x, y], dtype=np.float32)

#Get Equation of line that is perpendicular to line passing through a point
def line_verticle(line, point):
    '''get the verticle line from line across point'''
    if line[1] == 0:
        verticle = [0, -1, point[1]]
    else:
        if line[0] == 0:
            verticle = [1, 0, -point[0]]
        else:
            verticle = [-1./line[0], -1, point[1] - (-1/line[0] * point[0])]
    return verticle

# Convert a parallelogram to rectangle
def rectangle_from_parallelogram(poly):
    '''
    fit a rectangle from a parallelogram
    '''
    p0, p1, p2, p3 = poly
    angle_p0 = np.arccos(np.dot(p1-p0, p3-p0)/(np.linalg.norm(p0-p1) * np.linalg.norm(p3-p0)))
    if angle_p0 < 0.5 * np.pi:
        if np.linalg.norm(p0 - p1) > np.linalg.norm(p0-p3):
            # p0 and p2
            ## p0
            p2p3 = fit_line([p2[0], p3[0]], [p2[1], p3[1]])
            p2p3_verticle = line_verticle(p2p3, p0)

            new_p3 = line_cross_point(p2p3, p2p3_verticle)
            ## p2
            p0p1 = fit_line([p0[0], p1[0]], [p0[1], p1[1]])
            p0p1_verticle = line_verticle(p0p1, p2)

            new_p1 = line_cross_point(p0p1, p0p1_verticle)
            return np.array([p0, new_p1, p2, new_p3], dtype=np.float32)
        else:
            p1p2 = fit_line([p1[0], p2[0]], [p1[1], p2[1]])
            p1p2_verticle = line_verticle(p1p2, p0)

            new_p1 = line_cross_point(p1p2, p1p2_verticle)
            p0p3 = fit_line([p0[0], p3[0]], [p0[1], p3[1]])
            p0p3_verticle = line_verticle(p0p3, p2)

            new_p3 = line_cross_point(p0p3, p0p3_verticle)
            return np.array([p0, new_p1, p2, new_p3], dtype=np.float32)
    else:
        if np.linalg.norm(p0-p1) > np.linalg.norm(p0-p3):
            # p1 and p3
            ## p1
            p2p3 = fit_line([p2[0], p3[0]], [p2[1], p3[1]])
            p2p3_verticle = line_verticle(p2p3, p1)

            new_p2 = line_cross_point(p2p3, p2p3_verticle)
            ## p3
            p0p1 = fit_line([p0[0], p1[0]], [p0[1], p1[1]])
            p0p1_verticle = line_verticle(p0p1, p3)

            new_p0 = line_cross_point(p0p1, p0p1_verticle)
            return np.array([new_p0, p1, new_p2, p3], dtype=np.float32)
        else:
            p0p3 = fit_line([p0[0], p3[0]], [p0[1], p3[1]])
            p0p3_verticle = line_verticle(p0p3, p1)

            new_p0 = line_cross_point(p0p3, p0p3_verticle)
            p1p2 = fit_line([p1[0], p2[0]], [p1[1], p2[1]])
            p1p2_verticle = line_verticle(p1p2, p3)

            new_p2 = line_cross_point(p1p2, p1p2_verticle)
            return np.array([new_p0, p1, new_p2, p3], dtype=np.float32)

#Sorting a rectangle to get all point in clockwies manner
def sort_rectangle(poly):
    '''sort the four coordinates of the polygon, points in poly should be sorted clockwise'''
    # First find the lowest point
    p_lowest = np.argmax(poly[:, 1])
    if np.count_nonzero(poly[:, 1] == poly[p_lowest, 1]) == 2:
        # if the bottom line is parallel to x-axis, then p0 must be the upper-left corner
        p0_index = np.argmin(np.sum(poly, axis=1))
        p1_index = (p0_index + 1) % 4
        p2_index = (p0_index + 2) % 4
        p3_index = (p0_index + 3) % 4
        return poly[[p0_index, p1_index, p2_index, p3_index]], 0.
    else:
        # find the point that sits right to the lowest point
        p_lowest_right = (p_lowest - 1) % 4
        p_lowest_left = (p_lowest + 1) % 4
        angle = np.arctan(-(poly[p_lowest][1] - poly[p_lowest_right][1])/(poly[p_lowest][0] - poly[p_lowest_right][0]))
        # assert angle > 0
        if angle <= 0:
            print(angle, poly[p_lowest], poly[p_lowest_right])
        if angle/np.pi * 180 > 45:
            #this point is p2
            p2_index = p_lowest
            p1_index = (p2_index - 1) % 4
            p0_index = (p2_index - 2) % 4
            p3_index = (p2_index + 1) % 4
            return poly[[p0_index, p1_index, p2_index, p3_index]], -(np.pi/2 - angle)
        else:
            # this point is p3
            p3_index = p_lowest
            p0_index = (p3_index + 1) % 4
            p1_index = (p3_index + 2) % 4
            p2_index = (p3_index + 3) % 4
            return poly[[p0_index, p1_index, p2_index, p3_index]], angle


def restore_rectangle_rbox(origin, geometry):
    ''' Resotre rectangle tbox'''
    d = geometry[:, :4]
    angle = geometry[:, 4]
    # for angle > 0
    origin_0 = origin[angle >= 0]
    d_0 = d[angle >= 0]
    angle_0 = angle[angle >= 0]
    if origin_0.shape[0] > 0:
        p = np.array([np.zeros(d_0.shape[0]), -d_0[:, 0] - d_0[:, 2],
                      d_0[:, 1] + d_0[:, 3], -d_0[:, 0] - d_0[:, 2],
                      d_0[:, 1] + d_0[:, 3], np.zeros(d_0.shape[0]),
                      np.zeros(d_0.shape[0]), np.zeros(d_0.shape[0]),
                      d_0[:, 3], -d_0[:, 2]])
        p = p.transpose((1, 0)).reshape((-1, 5, 2))  # N*5*2

        rotate_matrix_x = np.array([np.cos(angle_0), np.sin(angle_0)]).transpose((1, 0))
        rotate_matrix_x = np.repeat(rotate_matrix_x, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))  # N*5*2

        rotate_matrix_y = np.array([-np.sin(angle_0), np.cos(angle_0)]).transpose((1, 0))
        rotate_matrix_y = np.repeat(rotate_matrix_y, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))

        p_rotate_x = np.sum(rotate_matrix_x * p, axis=2)[:, :, np.newaxis]  # N*5*1
        p_rotate_y = np.sum(rotate_matrix_y * p, axis=2)[:, :, np.newaxis]  # N*5*1

        p_rotate = np.concatenate([p_rotate_x, p_rotate_y], axis=2)  # N*5*2

        p3_in_origin = origin_0 - p_rotate[:, 4, :]
        new_p0 = p_rotate[:, 0, :] + p3_in_origin  # N*2
        new_p1 = p_rotate[:, 1, :] + p3_in_origin
        new_p2 = p_rotate[:, 2, :] + p3_in_origin
        new_p3 = p_rotate[:, 3, :] + p3_in_origin

        new_p_0 = np.concatenate([new_p0[:, np.newaxis, :], new_p1[:, np.newaxis, :],
                                  new_p2[:, np.newaxis, :], new_p3[:, np.newaxis, :]], axis=1)  # N*4*2
    else:
        new_p_0 = np.zeros((0, 4, 2))
    # for angle < 0
    origin_1 = origin[angle < 0]
    d_1 = d[angle < 0]
    angle_1 = angle[angle < 0]
    if origin_1.shape[0] > 0:
        p = np.array([-d_1[:, 1] - d_1[:, 3], -d_1[:, 0] - d_1[:, 2],
                      np.zeros(d_1.shape[0]), -d_1[:, 0] - d_1[:, 2],
                      np.zeros(d_1.shape[0]), np.zeros(d_1.shape[0]),
                      -d_1[:, 1] - d_1[:, 3], np.zeros(d_1.shape[0]),
                      -d_1[:, 1], -d_1[:, 2]])
        p = p.transpose((1, 0)).reshape((-1, 5, 2))  # N*5*2

        rotate_matrix_x = np.array([np.cos(-angle_1), -np.sin(-angle_1)]).transpose((1, 0))
        rotate_matrix_x = np.repeat(rotate_matrix_x, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))  # N*5*2

        rotate_matrix_y = np.array([np.sin(-angle_1), np.cos(-angle_1)]).transpose((1, 0))
        rotate_matrix_y = np.repeat(rotate_matrix_y, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))

        p_rotate_x = np.sum(rotate_matrix_x * p, axis=2)[:, :, np.newaxis]  # N*5*1
        p_rotate_y = np.sum(rotate_matrix_y * p, axis=2)[:, :, np.newaxis]  # N*5*1

        p_rotate = np.concatenate([p_rotate_x, p_rotate_y], axis=2)  # N*5*2

        p3_in_origin = origin_1 - p_rotate[:, 4, :]
        new_p0 = p_rotate[:, 0, :] + p3_in_origin  # N*2
        new_p1 = p_rotate[:, 1, :] + p3_in_origin
        new_p2 = p_rotate[:, 2, :] + p3_in_origin
        new_p3 = p_rotate[:, 3, :] + p3_in_origin

        new_p_1 = np.concatenate([new_p0[:, np.newaxis, :], new_p1[:, np.newaxis, :],
                                  new_p2[:, np.newaxis, :], new_p3[:, np.newaxis, :]], axis=1)  # N*4*2
    else:
        new_p_1 = np.zeros((0, 4, 2))
    return np.concatenate([new_p_0, new_p_1])


#Some geometrical functions used in codes
def restore_rectangle(origin, geometry):
    return restore_rectangle_rbox(origin, geometry)

def getRotateRect(box):
    rect = cv2.minAreaRect(box)

    angle=rect[2]  # angle = [-90, 0)
    if angle < -45:
        rect = (rect[0], (rect[1][0], rect[1][1]), rect[2])
        angle += 90
        size = (rect[1][1],rect[1][0])
    else:
        rect = (rect[0], (rect[1][0], rect[1][1]), rect[2])
        size=rect[1]

    box_ = cv2.boxPoints(rect)
    return np.concatenate([rect[0], size]), angle, box_


#These Functions are used to Generate ROI params like out box,crop box & angles that we use to crop text from image
def generate_roiRotatePara(box, angle, expand_w = 60):
    '''Generate all ROI Parameterts'''
    p0_rect, p1_rect, p2_rect, p3_rect = box
    cxy = (p0_rect + p2_rect) / 2.
    size = np.array([np.linalg.norm(p0_rect - p1_rect), np.linalg.norm(p0_rect - p3_rect)])
    rrect = np.concatenate([cxy, size])

    box=np.array(box)

    points=np.array(box, dtype=np.int32)
    xmin=np.min(points[:,0])
    xmax=np.max(points[:,0])
    ymin=np.min(points[:,1])
    ymax=np.max(points[:,1])
    bbox = np.array([xmin, ymin, xmax, ymax])
    if np.any(bbox < -expand_w):
        return None
    
    rrect[:2] -= bbox[:2]
    rrect[:2] -= rrect[2:] / 2
    rrect[2:] += rrect[:2]

    bbox[2:] -= bbox[:2]

    rrect[::2] = np.clip(rrect[::2], 0, bbox[2])
    rrect[1::2] = np.clip(rrect[1::2], 0, bbox[3])
    rrect[2:] -= rrect[:2]
    
    return bbox.astype(np.int32), rrect.astype(np.int32), - angle

def restore_roiRotatePara(box):
    rectange, rotate_angle = sort_rectangle(box)
    return generate_roiRotatePara(rectange, rotate_angle)

#This function is used to generate geo_map,score_map, training_mask,corp_box,out_box,angle that we use while training model
def generate_rbox(im_size, polys, tags):
    '''Genrate score_map and geo_map for image'''
    h, w = im_size
    poly_mask = np.zeros((h, w), dtype=np.uint8)
    score_map = np.zeros((h, w), dtype=np.uint8)
    geo_map = np.zeros((h, w, 5), dtype=np.float32)

    outBoxs = []
    cropBoxs = []
    angles = []
    text_tags = []
    recg_masks = []
    # mask used during traning, to ignore some hard areas
    training_mask = np.ones((h, w), dtype=np.uint8)
    for poly_idx, poly_tag in enumerate(zip(polys, tags)):
        poly = poly_tag[0]
        #print(poly)
        tag = poly_tag[1]
        #print(tag)
        r = [None, None, None, None]
        for i in range(4):
            r[i] = min(np.linalg.norm(poly[i] - poly[(i + 1) % 4]),
                       np.linalg.norm(poly[i] - poly[(i - 1) % 4]))
        # score map
        shrinked_poly = shrink_poly(poly.copy(), r).astype(np.int32)[np.newaxis, :, :]
        cv2.fillPoly(score_map, shrinked_poly, 1)
        cv2.fillPoly(poly_mask, shrinked_poly, poly_idx + 1)

        # if geometry == 'RBOX':
        # generate a parallelogram for any combination of two vertices
        fitted_parallelograms = []
        for i in range(4):
            p0 = poly[i]
            p1 = poly[(i + 1) % 4]
            p2 = poly[(i + 2) % 4]
            p3 = poly[(i + 3) % 4]
            edge = fit_line([p0[0], p1[0]], [p0[1], p1[1]])
            backward_edge = fit_line([p0[0], p3[0]], [p0[1], p3[1]])
            forward_edge = fit_line([p1[0], p2[0]], [p1[1], p2[1]])
            if point_dist_to_line(p0, p1, p2) > point_dist_to_line(p0, p1, p3):
                #  parallel lines through p2
                if edge[1] == 0:
                    edge_opposite = [1, 0, -p2[0]]
                else:
                    edge_opposite = [edge[0], -1, p2[1] - edge[0] * p2[0]]
            else:
                # after p3
                if edge[1] == 0:
                    edge_opposite = [1, 0, -p3[0]]
                else:
                    edge_opposite = [edge[0], -1, p3[1] - edge[0] * p3[0]]
            # move forward edge
            new_p0 = p0
            new_p1 = p1
            new_p2 = p2
            new_p3 = p3
            new_p2 = line_cross_point(forward_edge, edge_opposite)
            if point_dist_to_line(p1, new_p2, p0) > point_dist_to_line(p1, new_p2, p3):
                # across p0
                if forward_edge[1] == 0:
                    forward_opposite = [1, 0, -p0[0]]
                else:
                    forward_opposite = [forward_edge[0], -1, p0[1] - forward_edge[0] * p0[0]]
            else:
                # across p3
                if forward_edge[1] == 0:
                    forward_opposite = [1, 0, -p3[0]]
                else:
                    forward_opposite = [forward_edge[0], -1, p3[1] - forward_edge[0] * p3[0]]
            new_p0 = line_cross_point(forward_opposite, edge)
            new_p3 = line_cross_point(forward_opposite, edge_opposite)
            fitted_parallelograms.append([new_p0, new_p1, new_p2, new_p3, new_p0])
            # or move backward edge
            new_p0 = p0
            new_p1 = p1
            new_p2 = p2
            new_p3 = p3
            new_p3 = line_cross_point(backward_edge, edge_opposite)
            if point_dist_to_line(p0, p3, p1) > point_dist_to_line(p0, p3, p2):
                # across p1
                if backward_edge[1] == 0:
                    backward_opposite = [1, 0, -p1[0]]
                else:
                    backward_opposite = [backward_edge[0], -1, p1[1] - backward_edge[0] * p1[0]]
            else:
                # across p2
                if backward_edge[1] == 0:
                    backward_opposite = [1, 0, -p2[0]]
                else:
                    backward_opposite = [backward_edge[0], -1, p2[1] - backward_edge[0] * p2[0]]
            new_p1 = line_cross_point(backward_opposite, edge)
            new_p2 = line_cross_point(backward_opposite, edge_opposite)
            fitted_parallelograms.append([new_p0, new_p1, new_p2, new_p3, new_p0])
        areas = [Polygon(t).area for t in fitted_parallelograms]
        parallelogram = np.array(fitted_parallelograms[np.argmin(areas)][:-1], dtype=np.float32)
        # sort thie polygon
        parallelogram_coord_sum = np.sum(parallelogram, axis=1)
        min_coord_idx = np.argmin(parallelogram_coord_sum)
        parallelogram = parallelogram[
            [min_coord_idx, (min_coord_idx + 1) % 4, (min_coord_idx + 2) % 4, (min_coord_idx + 3) % 4]]

        rectange = rectangle_from_parallelogram(parallelogram)
        rectange, rotate_angle = sort_rectangle(rectange)

        p0_rect, p1_rect, p2_rect, p3_rect = rectange

        # if the poly is too small, then ignore it during training
        poly_h = min(np.linalg.norm(p0_rect - p3_rect), np.linalg.norm(p1_rect - p2_rect))
        poly_w = min(np.linalg.norm(p0_rect - p1_rect), np.linalg.norm(p2_rect - p3_rect))

        invaild = (min(poly_h, poly_w) < 6) or tag is None or (True and poly_h > poly_w * 2)

        if invaild:
            cv2.fillPoly(training_mask, poly.astype(np.int32)[np.newaxis, :, :], 0)
        xy_in_poly = np.argwhere(poly_mask == (poly_idx + 1))
        
        if not invaild:
            roiRotatePara = generate_roiRotatePara(rectange, rotate_angle)
            if roiRotatePara:
                outBox, cropBox, angle = roiRotatePara
                if min(cropBox[2:]) > 6:
                    w , h = cropBox[2:]
                    textImgW = np.ceil(min(w / float(h) * 32, 256) / 4 /1)
                    #print(tag)
                    if textImgW >= 2 * min(len(tag), 16):  # avoid CTC error
                        outBoxs.append(outBox)
                        cropBoxs.append(cropBox)
                        angles.append(angle)
                        text_tags.append(tag[:16])
                        recg_masks.append(1.)

        for y, x in xy_in_poly:
            point = np.array([x, y], dtype=np.float32)
            # top
            geo_map[y, x, 0] = point_dist_to_line(p0_rect, p1_rect, point) + 3
            # right
            geo_map[y, x, 1] = point_dist_to_line(p1_rect, p2_rect, point) + 3
            # down
            geo_map[y, x, 2] = point_dist_to_line(p2_rect, p3_rect, point) + 3
            # left
            geo_map[y, x, 3] = point_dist_to_line(p3_rect, p0_rect, point) + 3
            # angle
            geo_map[y, x, 4] = rotate_angle
    if len(outBoxs) == 0:
        outBoxs.append([0, 0, 2 * 4, 2 * 4]) # keep extract From sharedConv feature map not zero
        cropBoxs.append([0, 0, 2 * 4, 2 * 4])
        angles.append(0.)
        text_tags.append([NUM_CLASSES - 2])
        recg_masks.append(0.)

    outBoxs = np.array(outBoxs, np.int32)
    cropBoxs = np.array(cropBoxs, np.int32)
    angles = np.array(angles, np.float32)

    return score_map, geo_map, training_mask, (outBoxs, cropBoxs, angles), text_tags, recg_masks

# %% [markdown]
# # Let's Create the detection architecture and loading the saved model weights

# %%
# The references for the below code is taken from
# https://github.com/jiangxiluning/FOTS.PyTorch/tree/master/FOTS
# https://github.com/Pay20Y/FOTS_TF
# https://github.com/Masao-Taketani/FOTS_OCR
# https://github.com/sugam95/FOTS
# Creating a deconv layer which used in text detection branch
class Deconv_layer(tf.keras.layers.Layer):
    def __init__(self,name="deconv"):
        super().__init__(name)
        self.inp_size=0
        self.conv_layer=None
        self.upsample_layer=None
        self.batch_norm=None
    def build(self,imshape):
        self.inp_size=imshape
        self.batch_norm=tf.keras.layers.BatchNormalization()
        self.conv_layer=tf.keras.layers.Conv2D(filters=self.inp_size[-1]//2,kernel_size=3,padding='same',activation='relu',
                                               kernel_initializer=tf.keras.initializers.GlorotNormal(seed=12),use_bias=False)
        self.upsample_layer=tf.keras.layers.UpSampling2D(size=(2,2),interpolation='bilinear',data_format='channels_last',)
    def call(self,X):
    
        x1=self.upsample_layer(X)
        x1=self.conv_layer(x1)
        x1=self.batch_norm(x1)
        x1=tf.keras.activations.relu(x1)
        return x1



# The references for the below code is taken from
# https://github.com/jiangxiluning/FOTS.PyTorch/tree/master/FOTS
# https://github.com/Pay20Y/FOTS_TF
# https://github.com/Masao-Taketani/FOTS_OCR
# https://github.com/sugam95/FOTS
# Preparing Text Detection Model
# we have used RESNET50 pretrained on imagenet dataset for Shared Convolutions
resnet=tf.keras.applications.ResNet50(input_shape=(512,512,3),include_top=False,weights='imagenet')
tf.keras.backend.clear_session()
layers=resnet.layers
x1,x2,x3,x4=None,None,None,None
for i in range(len(layers)): 
    x=layers[i]
    if x.name=='pool1_pool':
        x1=x
    if x.name=='conv3_block1_1_conv':
        x2=x
    if x.name=='conv4_block1_1_conv':
        x3=x   
    if x.name=='conv5_block3_2_conv':
        x4=x  
m=x4.output
m=Deconv_layer('deconv_layer1')(m)
m=tf.keras.layers.add([m,x3.output])

m=Deconv_layer('deconv_layer2')(m)
m=tf.keras.layers.add([m,x2.output])

m=Deconv_layer('deconv_layer3')(m)
m=tf.keras.layers.add([m,x1.output])
m=tf.keras.layers.BatchNormalization()(m)
m=Deconv_layer('deconv_layer4')(m)
m=Deconv_layer('deconv_layer5')(m)
score=tf.keras.layers.Conv2D(1,kernel_size=3,padding='same',activation='sigmoid')(m)

# Used this because sigmoid gives values in range of 0-1(as mentioned in git repository)
geo_map=tf.keras.layers.Conv2D(4,kernel_size=3,padding='same',activation='sigmoid')(m)*512
# Angles are supposed to be within a range of [-45 to 45]
angle_map=(tf.keras.layers.Conv2D(1,kernel_size=3,padding='same',activation='sigmoid')(m)-0.5)*np.pi/2
out=tf.concat([score,geo_map,angle_map],axis=3)
detection_model=tf.keras.Model(resnet.input,out,name='detector')

for layers in resnet.layers:
     layers.trainable=False    

#Loading the saved weights of detection model
detection_model.load_weights('/content/drive/MyDrive/detection.h5')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 3s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Let's Create the Recognition architecture and loading the saved model weights

# %%
#Text Recognition Model
inputs = tf.keras.layers.Input(name='the_input', shape=(64,128,3), dtype='float32')  

inner = tf.keras.layers.Conv2D(64, (3, 3), padding='same', name='conv1', kernel_initializer='he_normal')(inputs) 
inner = tf.keras.layers.BatchNormalization()(inner)
inner = tf.keras.layers.Activation('relu')(inner)
inner = tf.keras.layers.MaxPooling2D(pool_size=(2, 1), name='max1')(inner)

inner = tf.keras.layers.Dropout(0.2)(inner)

inner = tf.keras.layers.Conv2D(64, (3, 3), padding='same', name='conv2', kernel_initializer='he_normal')(inner)  
inner = tf.keras.layers.BatchNormalization()(inner)
inner = tf.keras.layers.Activation('relu')(inner)
inner = tf.keras.layers.MaxPooling2D(pool_size=(2, 1), name='max2')(inner)

inner = tf.keras.layers.Dropout(0.2)(inner)

inner = tf.keras.layers.Conv2D(32, (3, 3), padding='same', name='conv3', kernel_initializer='he_normal')(inner)  
inner = tf.keras.layers.BatchNormalization()(inner)
inner = tf.keras.layers.Activation('relu')(inner)
inner = tf.keras.layers.Conv2D(32, (3, 3), padding='same', name='conv4', kernel_initializer='he_normal')(inner)  
inner = tf.keras.layers.BatchNormalization()(inner)
inner = tf.keras.layers.Activation('relu')(inner)
inner = tf.keras.layers.MaxPooling2D(pool_size=(2, 1), name='max3')(inner)  

inner = tf.keras.layers.Dropout(0.2)(inner)

inner = tf.keras.layers.Conv2D(32, (3, 3), padding='same', name='conv5', kernel_initializer='he_normal')(inner)  
inner = tf.keras.layers.BatchNormalization()(inner)
inner = tf.keras.layers.Activation('relu')(inner)
inner = tf.keras.layers.Conv2D(32, (3, 3), padding='same', name='conv6')(inner)   
inner = tf.keras.layers.BatchNormalization()(inner)
inner = tf.keras.layers.Activation('relu')(inner)
inner = tf.keras.layers.MaxPooling2D(pool_size=(2, 1), name='max4')(inner)  

inner = tf.keras.layers.Dropout(0.2)(inner)

inner = tf.keras.layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal', name='con7')(inner) 
inner = tf.keras.layers.BatchNormalization()(inner)
inner = tf.keras.layers.Activation('relu')(inner)
inner = tf.keras.layers.Reshape(target_shape=((64,512)), name='reshape')(inner)  
inner = tf.keras.layers.Dense(64, activation='relu', kernel_initializer='he_normal', name='dense1')(inner) 

out=tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32,return_sequences=True,go_backwards=True))(inner)
out=tf.keras.layers.Bidirectional(tf.keras.layers.GRU(128,return_sequences=True,go_backwards=True))(out)
x=tf.keras.layers.Dense(100)(out)#Here we hve given 100 because vocab size is 99 and 1 extra is for blank symbol
x=tf.keras.activations.softmax(x)
recognizer=tf.keras.models.Model(inputs,x)

# Save the weights
recognition_model.load_weights('/content/drive/MyDrive/recognition_model.h5')

# %% [markdown]
# # Let's Build the final pipeline for inferences

# %%
#These Are Function that will be used while converting geo_maps to score_maps and returns bounding boxes for image after nms

def sort_poly(p):
  min_axis = np.argmin(np.sum(p, axis=1))
  p = p[[min_axis, (min_axis+1)%4, (min_axis+2)%4, (min_axis+3)%4]]
  if abs(p[0, 0] - p[1, 0]) > abs(p[0, 1] - p[1, 1]):
    return p
  else:
    return p[[0, 3, 2, 1]]
def intersection(g, p):
    g = Polygon(g[:8].reshape((4, 2)))
    p = Polygon(p[:8].reshape((4, 2)))
    if not g.is_valid or not p.is_valid:
        return 0
    inter = Polygon(g).intersection(Polygon(p)).area
    union = g.area + p.area - inter
    if union == 0:
        return 0
    else:
        return inter/union


def weighted_merge(g, p):
    g[:8] = (g[8] * g[:8] + p[8] * p[:8])/(g[8] + p[8])
    g[8] = (g[8] + p[8])
    return g


def standard_nms(S, thres):
    order = np.argsort(S[:, 8])[::-1]
    keep = []
    while order.size > 0:
        i = order[0]
        keep.append(i)
        ovr = np.array([intersection(S[i], S[t]) for t in order[1:]])

        inds = np.where(ovr <= thres)[0]
        order = order[inds+1]

    return S[keep]


def nms_locality(polys, thres=0.3):
    '''
    :param polys: a N*9 numpy array. first 8 coordinates, then prob
    :return: boxes after nms
    '''
    S = []
    p = None
  
    for g in polys:
        if p is not None and intersection(g, p) > thres:
        
            p = weighted_merge(g, p)
        else:
            if p is not None:
                S.append(p)
            p = g
  
    if p is not None:
        S.append(p)

    if len(S) == 0:
        return np.array([])
    
    return standard_nms(np.array(S), thres)

# %%
#Preparing vocabulary for Text Recognition Branch
CHAR_VECTOR = " 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZÉ´-~`<>'.:;^/|!?$%#@&*()[]{}_+=,\\\""
NUM_CLASSES = len(CHAR_VECTOR) 
char_index={}
index_char={}
for i,val in enumerate(CHAR_VECTOR):
  index_char[i+1]=val
  char_index[val]=i+1

# %%
#This is final Inference function used for complete FOTS pipeline
def Final_Pipeline(img):
  '''This function is main complete pipeline of our Model'''
  start_time=time.time()
  
  #1.Text Detection
  img=cv2.resize(img,(512,512))
  ii=detector.predict(np.expand_dims(img,axis=0))
  score_map=ii[0][:,:,0]
  geo_map=ii[0][:,:,1:]
  for ind in [0,1,2,3,4]:
    geo_map[:,:,ind]*=score_map

  #2.ROI Rotate  
  score_map_thresh=0.5
  box_thresh=0.1 
  nms_thres=0.2
  if len(score_map.shape) == 4:
    score_map = score_map[0, :, :, 0]
    geo_map = geo_map[0, :, :, :]

  # filter the score map
  xy_text = np.argwhere(score_map > score_map_thresh)

  # sort the text boxes via the y axis
  xy_text = xy_text[np.argsort(xy_text[:, 0])]

  # restore
  text_box_restored = restore_rectangle(xy_text[:, ::-1], geo_map[xy_text[:, 0], xy_text[:, 1], :]) # N*4*2
  boxes = np.zeros((text_box_restored.shape[0], 9), dtype=np.float32)
  boxes[:, :8] = text_box_restored.reshape((-1, 8))
  boxes[:, 8] = score_map[xy_text[:, 0], xy_text[:, 1]]
  boxes = nms_locality(boxes.astype(np.float64), nms_thres)
  

  # here we filter some low score boxes by the average score map, this is different from the orginal paper
  for i, box in enumerate(boxes):
    mask = np.zeros_like(score_map, dtype=np.uint8)
    cv2.fillPoly(mask, box[:8].reshape((-1, 4, 2)).astype(np.int32), 1)
    boxes[i, 8] = cv2.mean(score_map, mask)[0]
    if i==4:
      break
  if len(boxes)>0:
    boxes = boxes[boxes[:, 8] > box_thresh]
  boxes[:,:8:2] = np.clip(boxes[:,:8:2], 0, 512 - 1)
  boxes[:,1:8:2] = np.clip(boxes[:,1:8:2], 0, 512 - 1)  
  res = []
  result = []
  if len(boxes)>0:
    for box in boxes:
      box_ =  box[:8].reshape((4, 2))
      if np.linalg.norm(box_[0] - box_[1]) < 8 or np.linalg.norm(box_[3]-box_[0]) < 8:
        continue
      result.append(box_)
  res.append(np.array(result, np.float32))   

  box_index = []
  brotateParas = []
  filter_bsharedFeatures = []
  for i in range(len(res)):
    rotateParas = []
    rboxes=res[i]
    txt=[]
    for j, rbox in enumerate(rboxes):
      para = restore_roiRotatePara(rbox)
      if para and min(para[1][2:]) > 8:
        rotateParas.append(para)
        box_index.append((i, j))
    pts=[]   
    
    
    #3. Text Recognition (From boxes given by Text Detection+ROI Rotate) 
    if len(rotateParas) > 0:
      for num in range(len(rotateParas)):
        text=""
        out=rotateParas[num][0]
        crop=rotateParas[num][1]
        points=np.array([[out[0],out[1]],[out[0]+out[2],out[1]],[out[0]+out[2],out[1]+out[3]],[out[0],out[1]+out[3]]])
        angle=rotateParas[num][2] 
        img1=tf.image.crop_to_bounding_box(img,out[1],out[0],out[3],out[2])
        img2=tf.keras.preprocessing.image.random_rotation(img1,angle)
        img2=tf.image.crop_to_bounding_box(img2,crop[1],crop[0],crop[3],crop[2]).numpy()
        img2=cv2.resize(img2,(128,64))
        img2=cv2.detailEnhance(img2)
        ii=recognizer.predict(np.expand_dims(img2,axis=0))
        arr=tf.keras.backend.ctc_decode(ii,np.ones((1),'int8')*64,)
        for val in arr[0][0].numpy()[0]:
          if val==-1:
            break
          else:
            text+=index_char[val]
        txt.append(text)
        pts.append(points)
    
    # 4. Labeling detected and Recognized Text in Image  
    for i in range(len(txt)):
      cv2.polylines(img,[pts[i]],isClosed=True,color=(0,255,0),thickness=1)
      cv2.putText(img,txt[i],(pts[i][0][0],pts[i][0][1]),cv2.FONT_HERSHEY_SIMPLEX,1, (200,50,0), 2)
    end_time=time.time()
    print("Time Taken By Pipeline="+str(end_time-start_time)+" seconds")  
    return img,txt

# %% [markdown]
# # Visualizing the results

# %%
# !wget --header="Host: rrc.cvc.uab.es" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7,hi;q=0.6" --header="Referer: https://rrc.cvc.uab.es/?ch=4&com=downloads" --header="Cookie: _ga=GA1.2.567376463.1614948806; PHPSESSID=f2rmmqdv6bur83qvu12pg6bdip; _gid=GA1.2.297659251.1616264264" --header="Connection: keep-alive" "https://rrc.cvc.uab.es/downloads/ch4_training_images.zip" -c -O 'ch4_training_images.zip' --no-check-certificate

# !unzip "/content/ch4_training_images.zip" -d "icadar_1000/"
# Out:
# --2021-06-20 10:01:38--  https://rrc.cvc.uab.es/downloads/ch4_training_images.zip
# Resolving rrc.cvc.uab.es (rrc.cvc.uab.es)... 158.109.8.55
# Connecting to rrc.cvc.uab.es (rrc.cvc.uab.es)|158.109.8.55|:443... connected.
# WARNING: cannot verify rrc.cvc.uab.es's certificate, issued by ‘CN=GEANT OV RSA CA 4,O=GEANT Vereniging,C=NL’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 90667586 (86M) [application/zip]
# Saving to: ‘ch4_training_images.zip’
#
# ch4_training_images 100%[===================>]  86.47M  1.74MB/s    in 56s
#
# 2021-06-20 10:02:35 (1.56 MB/s) - ‘ch4_training_images.zip’ saved [90667586/90667586]
#
# Archive:  /content/ch4_training_images.zip
#   inflating: icadar_1000/img_1.jpg
#   inflating: icadar_1000/img_2.jpg
#   inflating: icadar_1000/img_3.jpg
#   inflating: icadar_1000/img_4.jpg
#   inflating: icadar_1000/img_5.jpg
#   inflating: icadar_1000/img_6.jpg
#   inflating: icadar_1000/img_7.jpg
#   inflating: icadar_1000/img_8.jpg
#   inflating: icadar_1000/img_9.jpg
#   inflating: icadar_1000/img_10.jpg
#   inflating: icadar_1000/img_11.jpg
#   inflating: icadar_1000/img_12.jpg
#   inflating: icadar_1000/img_13.jpg
#   inflating: icadar_1000/img_14.jpg
#   inflating: icadar_1000/img_15.jpg
#   inflating: icadar_1000/img_16.jpg
#   inflating: icadar_1000/img_17.jpg
#   inflating: icadar_1000/img_18.jpg
#   inflating: icadar_1000/img_19.jpg
#   inflating: icadar_1000/img_20.jpg
#   inflating: icadar_1000/img_21.jpg
#   inflating: icadar_1000/img_22.jpg
#   inflating: icadar_1000/img_23.jpg
#   inflating: icadar_1000/img_24.jpg
#   inflating: icadar_1000/img_25.jpg
#   inflating: icadar_1000/img_26.jpg
#   inflating: icadar_1000/img_27.jpg
#   inflating: icadar_1000/img_28.jpg
#   inflating: icadar_1000/img_29.jpg
#   inflating: icadar_1000/img_30.jpg
#   inflating: icadar_1000/img_31.jpg
#   inflating: icadar_1000/img_32.jpg
#   inflating: icadar_1000/img_33.jpg
#   inflating: icadar_1000/img_34.jpg
#   inflating: icadar_1000/img_35.jpg
#   inflating: icadar_1000/img_36.jpg
#   inflating: icadar_1000/img_37.jpg
#   inflating: icadar_1000/img_38.jpg
#   inflating: icadar_1000/img_39.jpg
#   inflating: icadar_1000/img_40.jpg
#   inflating: icadar_1000/img_41.jpg
#   inflating: icadar_1000/img_42.jpg
#   inflating: icadar_1000/img_43.jpg
#   inflating: icadar_1000/img_44.jpg
#   inflating: icadar_1000/img_45.jpg
#   inflating: icadar_1000/img_46.jpg
#   inflating: icadar_1000/img_47.jpg
#   inflating: icadar_1000/img_48.jpg
#   inflating: icadar_1000/img_49.jpg
#   inflating: icadar_1000/img_50.jpg
#   inflating: icadar_1000/img_51.jpg
#   inflating: icadar_1000/img_52.jpg
#   inflating: icadar_1000/img_53.jpg
#   inflating: icadar_1000/img_54.jpg
#   inflating: icadar_1000/img_55.jpg
#   inflating: icadar_1000/img_56.jpg
#   inflating: icadar_1000/img_57.jpg
#   inflating: icadar_1000/img_58.jpg
#   inflating: icadar_1000/img_59.jpg
#   inflating: icadar_1000/img_60.jpg
#   inflating: icadar_1000/img_61.jpg
#   inflating: icadar_1000/img_62.jpg
#   inflating: icadar_1000/img_63.jpg
#   inflating: icadar_1000/img_64.jpg
#   inflating: icadar_1000/img_65.jpg
#   inflating: icadar_1000/img_66.jpg
#   inflating: icadar_1000/img_67.jpg
#   inflating: icadar_1000/img_68.jpg
#   inflating: icadar_1000/img_69.jpg
#   inflating: icadar_1000/img_70.jpg
#   inflating: icadar_1000/img_71.jpg
#   inflating: icadar_1000/img_72.jpg
#   inflating: icadar_1000/img_73.jpg
#   inflating: icadar_1000/img_74.jpg
#   inflating: icadar_1000/img_75.jpg
#   inflating: icadar_1000/img_76.jpg
#   inflating: icadar_1000/img_77.jpg
#   inflating: icadar_1000/img_78.jpg
#   inflating: icadar_1000/img_79.jpg
#   inflating: icadar_1000/img_80.jpg
#   inflating: icadar_1000/img_81.jpg
#   inflating: icadar_1000/img_82.jpg
#   inflating: icadar_1000/img_83.jpg
#   inflating: icadar_1000/img_84.jpg
#   inflating: icadar_1000/img_85.jpg
#   inflating: icadar_1000/img_86.jpg
#   inflating: icadar_1000/img_87.jpg
#   inflating: icadar_1000/img_88.jpg
#   inflating: icadar_1000/img_89.jpg
#   inflating: icadar_1000/img_90.jpg
#   inflating: icadar_1000/img_91.jpg
#   inflating: icadar_1000/img_92.jpg
#   inflating: icadar_1000/img_93.jpg
#   inflating: icadar_1000/img_94.jpg
#   inflating: icadar_1000/img_95.jpg
#   inflating: icadar_1000/img_96.jpg
#   inflating: icadar_1000/img_97.jpg
#   inflating: icadar_1000/img_98.jpg
#   inflating: icadar_1000/img_99.jpg
#   inflating: icadar_1000/img_100.jpg
#   inflating: icadar_1000/img_101.jpg
#   inflating: icadar_1000/img_102.jpg
#   inflating: icadar_1000/img_103.jpg
#   inflating: icadar_1000/img_104.jpg
#   inflating: icadar_1000/img_105.jpg
#   inflating: icadar_1000/img_106.jpg
#   inflating: icadar_1000/img_107.jpg
#   inflating: icadar_1000/img_108.jpg
#   inflating: icadar_1000/img_109.jpg
#   inflating: icadar_1000/img_110.jpg
#   inflating: icadar_1000/img_111.jpg
#   inflating: icadar_1000/img_112.jpg
#   inflating: icadar_1000/img_113.jpg
#   inflating: icadar_1000/img_114.jpg
#   inflating: icadar_1000/img_115.jpg
#   inflating: icadar_1000/img_116.jpg
#   inflating: icadar_1000/img_117.jpg
#   inflating: icadar_1000/img_118.jpg
#   inflating: icadar_1000/img_119.jpg
#   inflating: icadar_1000/img_120.jpg
#   inflating: icadar_1000/img_121.jpg
#   inflating: icadar_1000/img_122.jpg
#   inflating: icadar_1000/img_123.jpg
#   inflating: icadar_1000/img_124.jpg
#   inflating: icadar_1000/img_125.jpg
#   inflating: icadar_1000/img_126.jpg
#   inflating: icadar_1000/img_127.jpg
#   inflating: icadar_1000/img_128.jpg
#   inflating: icadar_1000/img_129.jpg
#   inflating: icadar_1000/img_130.jpg
#   inflating: icadar_1000/img_131.jpg
#   inflating: icadar_1000/img_132.jpg
#   inflating: icadar_1000/img_133.jpg
#   inflating: icadar_1000/img_134.jpg
#   inflating: icadar_1000/img_135.jpg
#   inflating: icadar_1000/img_136.jpg
#   inflating: icadar_1000/img_137.jpg
#   inflating: icadar_1000/img_138.jpg
#   inflating: icadar_1000/img_139.jpg
#   inflating: icadar_1000/img_140.jpg
#   inflating: icadar_1000/img_141.jpg
#   inflating: icadar_1000/img_142.jpg
#   inflating: icadar_1000/img_143.jpg
#   inflating: icadar_1000/img_144.jpg
#   inflating: icadar_1000/img_145.jpg
#   inflating: icadar_1000/img_146.jpg
#   inflating: icadar_1000/img_147.jpg
#   inflating: icadar_1000/img_148.jpg
#   inflating: icadar_1000/img_149.jpg
#   inflating: icadar_1000/img_150.jpg
#   inflating: icadar_1000/img_151.jpg
#   inflating: icadar_1000/img_152.jpg
#   inflating: icadar_1000/img_153.jpg
#   inflating: icadar_1000/img_154.jpg
#   inflating: icadar_1000/img_155.jpg
#   inflating: icadar_1000/img_156.jpg
#   inflating: icadar_1000/img_157.jpg
#   inflating: icadar_1000/img_158.jpg
#   inflating: icadar_1000/img_159.jpg
#   inflating: icadar_1000/img_160.jpg
#   inflating: icadar_1000/img_161.jpg
#   inflating: icadar_1000/img_162.jpg
#   inflating: icadar_1000/img_163.jpg
#   inflating: icadar_1000/img_164.jpg
#   inflating: icadar_1000/img_165.jpg
#   inflating: icadar_1000/img_166.jpg
#   inflating: icadar_1000/img_167.jpg
#   inflating: icadar_1000/img_168.jpg
#   inflating: icadar_1000/img_169.jpg
#   inflating: icadar_1000/img_170.jpg
#   inflating: icadar_1000/img_171.jpg
#   inflating: icadar_1000/img_172.jpg
#   inflating: icadar_1000/img_173.jpg
#   inflating: icadar_1000/img_174.jpg
#   inflating: icadar_1000/img_175.jpg
#   inflating: icadar_1000/img_176.jpg
#   inflating: icadar_1000/img_177.jpg
#   inflating: icadar_1000/img_178.jpg
#   inflating: icadar_1000/img_179.jpg
#   inflating: icadar_1000/img_180.jpg
#   inflating: icadar_1000/img_181.jpg
#   inflating: icadar_1000/img_182.jpg
#   inflating: icadar_1000/img_183.jpg
#   inflating: icadar_1000/img_184.jpg
#   inflating: icadar_1000/img_185.jpg
#   inflating: icadar_1000/img_186.jpg
#   inflating: icadar_1000/img_187.jpg
#   inflating: icadar_1000/img_188.jpg
#   inflating: icadar_1000/img_189.jpg
#   inflating: icadar_1000/img_190.jpg
#   inflating: icadar_1000/img_191.jpg
#   inflating: icadar_1000/img_192.jpg
#   inflating: icadar_1000/img_193.jpg
#   inflating: icadar_1000/img_194.jpg
#   inflating: icadar_1000/img_195.jpg
#   inflating: icadar_1000/img_196.jpg
#   inflating: icadar_1000/img_197.jpg
#   inflating: icadar_1000/img_198.jpg
#   inflating: icadar_1000/img_199.jpg
#   inflating: icadar_1000/img_200.jpg
#   inflating: icadar_1000/img_201.jpg
#   inflating: icadar_1000/img_202.jpg
#   inflating: icadar_1000/img_203.jpg
#   inflating: icadar_1000/img_204.jpg
#   inflating: icadar_1000/img_205.jpg
#   inflating: icadar_1000/img_206.jpg
#   inflating: icadar_1000/img_207.jpg
#   inflating: icadar_1000/img_208.jpg
#   inflating: icadar_1000/img_209.jpg
#   inflating: icadar_1000/img_210.jpg
#   inflating: icadar_1000/img_211.jpg
#   inflating: icadar_1000/img_212.jpg
#   inflating: icadar_1000/img_213.jpg
#   inflating: icadar_1000/img_214.jpg
#   inflating: icadar_1000/img_215.jpg
#   inflating: icadar_1000/img_216.jpg
#   inflating: icadar_1000/img_217.jpg
#   inflating: icadar_1000/img_218.jpg
#   inflating: icadar_1000/img_219.jpg
#   inflating: icadar_1000/img_220.jpg
#   inflating: icadar_1000/img_221.jpg
#   inflating: icadar_1000/img_222.jpg
#   inflating: icadar_1000/img_223.jpg
#   inflating: icadar_1000/img_224.jpg
#   inflating: icadar_1000/img_225.jpg
#   inflating: icadar_1000/img_226.jpg
#   inflating: icadar_1000/img_227.jpg
#   inflating: icadar_1000/img_228.jpg
#   inflating: icadar_1000/img_229.jpg
#   inflating: icadar_1000/img_230.jpg
#   inflating: icadar_1000/img_231.jpg
#   inflating: icadar_1000/img_232.jpg
#   inflating: icadar_1000/img_233.jpg
#   inflating: icadar_1000/img_234.jpg
#   inflating: icadar_1000/img_235.jpg
#   inflating: icadar_1000/img_236.jpg
#   inflating: icadar_1000/img_237.jpg
#   inflating: icadar_1000/img_238.jpg
#   inflating: icadar_1000/img_239.jpg
#   inflating: icadar_1000/img_240.jpg
#   inflating: icadar_1000/img_241.jpg
#   inflating: icadar_1000/img_242.jpg
#   inflating: icadar_1000/img_243.jpg
#   inflating: icadar_1000/img_244.jpg
#   inflating: icadar_1000/img_245.jpg
#   inflating: icadar_1000/img_246.jpg
#   inflating: icadar_1000/img_247.jpg
#   inflating: icadar_1000/img_248.jpg
#   inflating: icadar_1000/img_249.jpg
#   inflating: icadar_1000/img_250.jpg
#   inflating: icadar_1000/img_251.jpg
#   inflating: icadar_1000/img_252.jpg
#   inflating: icadar_1000/img_253.jpg
#   inflating: icadar_1000/img_254.jpg
#   inflating: icadar_1000/img_255.jpg
#   inflating: icadar_1000/img_256.jpg
#   inflating: icadar_1000/img_257.jpg
#   inflating: icadar_1000/img_258.jpg
#   inflating: icadar_1000/img_259.jpg
#   inflating: icadar_1000/img_260.jpg
#   inflating: icadar_1000/img_261.jpg
#   inflating: icadar_1000/img_262.jpg
#   inflating: icadar_1000/img_263.jpg
#   inflating: icadar_1000/img_264.jpg
#   inflating: icadar_1000/img_265.jpg
#   inflating: icadar_1000/img_266.jpg
#   inflating: icadar_1000/img_267.jpg
#   inflating: icadar_1000/img_268.jpg
#   inflating: icadar_1000/img_269.jpg
#   inflating: icadar_1000/img_270.jpg
#   inflating: icadar_1000/img_271.jpg
#   inflating: icadar_1000/img_272.jpg
#   inflating: icadar_1000/img_273.jpg
#   inflating: icadar_1000/img_274.jpg
#   inflating: icadar_1000/img_275.jpg
#   inflating: icadar_1000/img_276.jpg
#   inflating: icadar_1000/img_277.jpg
#   inflating: icadar_1000/img_278.jpg
#   inflating: icadar_1000/img_279.jpg
#   inflating: icadar_1000/img_280.jpg
#   inflating: icadar_1000/img_281.jpg
#   inflating: icadar_1000/img_282.jpg
#   inflating: icadar_1000/img_283.jpg
#   inflating: icadar_1000/img_284.jpg
#   inflating: icadar_1000/img_285.jpg
#   inflating: icadar_1000/img_286.jpg
#   inflating: icadar_1000/img_287.jpg
#   inflating: icadar_1000/img_288.jpg
#   inflating: icadar_1000/img_289.jpg
#   inflating: icadar_1000/img_290.jpg
#   inflating: icadar_1000/img_291.jpg
#   inflating: icadar_1000/img_292.jpg
#   inflating: icadar_1000/img_293.jpg
#   inflating: icadar_1000/img_294.jpg
#   inflating: icadar_1000/img_295.jpg
#   inflating: icadar_1000/img_296.jpg
#   inflating: icadar_1000/img_297.jpg
#   inflating: icadar_1000/img_298.jpg
#   inflating: icadar_1000/img_299.jpg
#   inflating: icadar_1000/img_300.jpg
#   inflating: icadar_1000/img_301.jpg
#   inflating: icadar_1000/img_302.jpg
#   inflating: icadar_1000/img_303.jpg
#   inflating: icadar_1000/img_304.jpg
#   inflating: icadar_1000/img_305.jpg
#   inflating: icadar_1000/img_306.jpg
#   inflating: icadar_1000/img_307.jpg
#   inflating: icadar_1000/img_308.jpg
#   inflating: icadar_1000/img_309.jpg
#   inflating: icadar_1000/img_310.jpg
#   inflating: icadar_1000/img_311.jpg
#   inflating: icadar_1000/img_312.jpg
#   inflating: icadar_1000/img_313.jpg
#   inflating: icadar_1000/img_314.jpg
#   inflating: icadar_1000/img_315.jpg
#   inflating: icadar_1000/img_316.jpg
#   inflating: icadar_1000/img_317.jpg
#   inflating: icadar_1000/img_318.jpg
#   inflating: icadar_1000/img_319.jpg
#   inflating: icadar_1000/img_320.jpg
#   inflating: icadar_1000/img_321.jpg
#   inflating: icadar_1000/img_322.jpg
#   inflating: icadar_1000/img_323.jpg
#   inflating: icadar_1000/img_324.jpg
#   inflating: icadar_1000/img_325.jpg
#   inflating: icadar_1000/img_326.jpg
#   inflating: icadar_1000/img_327.jpg
#   inflating: icadar_1000/img_328.jpg
#   inflating: icadar_1000/img_329.jpg
#   inflating: icadar_1000/img_330.jpg
#   inflating: icadar_1000/img_331.jpg
#   inflating: icadar_1000/img_332.jpg
#   inflating: icadar_1000/img_333.jpg
#   inflating: icadar_1000/img_334.jpg
#   inflating: icadar_1000/img_335.jpg
#   inflating: icadar_1000/img_336.jpg
#   inflating: icadar_1000/img_337.jpg
#   inflating: icadar_1000/img_338.jpg
#   inflating: icadar_1000/img_339.jpg
#   inflating: icadar_1000/img_340.jpg
#   inflating: icadar_1000/img_341.jpg
#   inflating: icadar_1000/img_342.jpg
#   inflating: icadar_1000/img_343.jpg
#   inflating: icadar_1000/img_344.jpg
#   inflating: icadar_1000/img_345.jpg
#   inflating: icadar_1000/img_346.jpg
#   inflating: icadar_1000/img_347.jpg
#   inflating: icadar_1000/img_348.jpg
#   inflating: icadar_1000/img_349.jpg
#   inflating: icadar_1000/img_350.jpg
#   inflating: icadar_1000/img_351.jpg
#   inflating: icadar_1000/img_352.jpg
#   inflating: icadar_1000/img_353.jpg
#   inflating: icadar_1000/img_354.jpg
#   inflating: icadar_1000/img_355.jpg
#   inflating: icadar_1000/img_356.jpg
#   inflating: icadar_1000/img_357.jpg
#   inflating: icadar_1000/img_358.jpg
#   inflating: icadar_1000/img_359.jpg
#   inflating: icadar_1000/img_360.jpg
#   inflating: icadar_1000/img_361.jpg
#   inflating: icadar_1000/img_362.jpg
#   inflating: icadar_1000/img_363.jpg
#   inflating: icadar_1000/img_364.jpg
#   inflating: icadar_1000/img_365.jpg
#   inflating: icadar_1000/img_366.jpg
#   inflating: icadar_1000/img_367.jpg
#   inflating: icadar_1000/img_368.jpg
#   inflating: icadar_1000/img_369.jpg
#   inflating: icadar_1000/img_370.jpg
#   inflating: icadar_1000/img_371.jpg
#   inflating: icadar_1000/img_372.jpg
#   inflating: icadar_1000/img_373.jpg
#   inflating: icadar_1000/img_374.jpg
#   inflating: icadar_1000/img_375.jpg
#   inflating: icadar_1000/img_376.jpg
#   inflating: icadar_1000/img_377.jpg
#   inflating: icadar_1000/img_378.jpg
#   inflating: icadar_1000/img_379.jpg
#   inflating: icadar_1000/img_380.jpg
#   inflating: icadar_1000/img_381.jpg
#   inflating: icadar_1000/img_382.jpg
#   inflating: icadar_1000/img_383.jpg
#   inflating: icadar_1000/img_384.jpg
#   inflating: icadar_1000/img_385.jpg
#   inflating: icadar_1000/img_386.jpg
#   inflating: icadar_1000/img_387.jpg
#   inflating: icadar_1000/img_388.jpg
#   inflating: icadar_1000/img_389.jpg
#   inflating: icadar_1000/img_390.jpg
#   inflating: icadar_1000/img_391.jpg
#   inflating: icadar_1000/img_392.jpg
#   inflating: icadar_1000/img_393.jpg
#   inflating: icadar_1000/img_394.jpg
#   inflating: icadar_1000/img_395.jpg
#   inflating: icadar_1000/img_396.jpg
#   inflating: icadar_1000/img_397.jpg
#   inflating: icadar_1000/img_398.jpg
#   inflating: icadar_1000/img_399.jpg
#   inflating: icadar_1000/img_400.jpg
#   inflating: icadar_1000/img_401.jpg
#   inflating: icadar_1000/img_402.jpg
#   inflating: icadar_1000/img_403.jpg
#   inflating: icadar_1000/img_404.jpg
#   inflating: icadar_1000/img_405.jpg
#   inflating: icadar_1000/img_406.jpg
#   inflating: icadar_1000/img_407.jpg
#   inflating: icadar_1000/img_408.jpg
#   inflating: icadar_1000/img_409.jpg
#   inflating: icadar_1000/img_410.jpg
#   inflating: icadar_1000/img_411.jpg
#   inflating: icadar_1000/img_412.jpg
#   inflating: icadar_1000/img_413.jpg
#   inflating: icadar_1000/img_414.jpg
#   inflating: icadar_1000/img_415.jpg
#   inflating: icadar_1000/img_416.jpg
#   inflating: icadar_1000/img_417.jpg
#   inflating: icadar_1000/img_418.jpg
#   inflating: icadar_1000/img_419.jpg
#   inflating: icadar_1000/img_420.jpg
#   inflating: icadar_1000/img_421.jpg
#   inflating: icadar_1000/img_422.jpg
#   inflating: icadar_1000/img_423.jpg
#   inflating: icadar_1000/img_424.jpg
#   inflating: icadar_1000/img_425.jpg
#   inflating: icadar_1000/img_426.jpg
#   inflating: icadar_1000/img_427.jpg
#   inflating: icadar_1000/img_428.jpg
#   inflating: icadar_1000/img_429.jpg
#   inflating: icadar_1000/img_430.jpg
#   inflating: icadar_1000/img_431.jpg
#   inflating: icadar_1000/img_432.jpg
#   inflating: icadar_1000/img_433.jpg
#   inflating: icadar_1000/img_434.jpg
#   inflating: icadar_1000/img_435.jpg
#   inflating: icadar_1000/img_436.jpg
#   inflating: icadar_1000/img_437.jpg
#   inflating: icadar_1000/img_438.jpg
#   inflating: icadar_1000/img_439.jpg
#   inflating: icadar_1000/img_440.jpg
#   inflating: icadar_1000/img_441.jpg
#   inflating: icadar_1000/img_442.jpg
#   inflating: icadar_1000/img_443.jpg
#   inflating: icadar_1000/img_444.jpg
#   inflating: icadar_1000/img_445.jpg
#   inflating: icadar_1000/img_446.jpg
#   inflating: icadar_1000/img_447.jpg
#   inflating: icadar_1000/img_448.jpg
#   inflating: icadar_1000/img_449.jpg
#   inflating: icadar_1000/img_450.jpg
#   inflating: icadar_1000/img_451.jpg
#   inflating: icadar_1000/img_452.jpg
#   inflating: icadar_1000/img_453.jpg
#   inflating: icadar_1000/img_454.jpg
#   inflating: icadar_1000/img_455.jpg
#   inflating: icadar_1000/img_456.jpg
#   inflating: icadar_1000/img_457.jpg
#   inflating: icadar_1000/img_458.jpg
#   inflating: icadar_1000/img_459.jpg
#   inflating: icadar_1000/img_460.jpg
#   inflating: icadar_1000/img_461.jpg
#   inflating: icadar_1000/img_462.jpg
#   inflating: icadar_1000/img_463.jpg
#   inflating: icadar_1000/img_464.jpg
#   inflating: icadar_1000/img_465.jpg
#   inflating: icadar_1000/img_466.jpg
#   inflating: icadar_1000/img_467.jpg
#   inflating: icadar_1000/img_468.jpg
#   inflating: icadar_1000/img_469.jpg
#   inflating: icadar_1000/img_470.jpg
#   inflating: icadar_1000/img_471.jpg
#   inflating: icadar_1000/img_472.jpg
#   inflating: icadar_1000/img_473.jpg
#   inflating: icadar_1000/img_474.jpg
#   inflating: icadar_1000/img_475.jpg
#   inflating: icadar_1000/img_476.jpg
#   inflating: icadar_1000/img_477.jpg
#   inflating: icadar_1000/img_478.jpg
#   inflating: icadar_1000/img_479.jpg
#   inflating: icadar_1000/img_480.jpg
#   inflating: icadar_1000/img_481.jpg
#   inflating: icadar_1000/img_482.jpg
#   inflating: icadar_1000/img_483.jpg
#   inflating: icadar_1000/img_484.jpg
#   inflating: icadar_1000/img_485.jpg
#   inflating: icadar_1000/img_486.jpg
#   inflating: icadar_1000/img_487.jpg
#   inflating: icadar_1000/img_488.jpg
#   inflating: icadar_1000/img_489.jpg
#   inflating: icadar_1000/img_490.jpg
#   inflating: icadar_1000/img_491.jpg
#   inflating: icadar_1000/img_492.jpg
#   inflating: icadar_1000/img_493.jpg
#   inflating: icadar_1000/img_494.jpg
#   inflating: icadar_1000/img_495.jpg
#   inflating: icadar_1000/img_496.jpg
#   inflating: icadar_1000/img_497.jpg
#   inflating: icadar_1000/img_498.jpg
#   inflating: icadar_1000/img_499.jpg
#   inflating: icadar_1000/img_500.jpg
#   inflating: icadar_1000/img_501.jpg
#   inflating: icadar_1000/img_502.jpg
#   inflating: icadar_1000/img_503.jpg
#   inflating: icadar_1000/img_504.jpg
#   inflating: icadar_1000/img_505.jpg
#   inflating: icadar_1000/img_506.jpg
#   inflating: icadar_1000/img_507.jpg
#   inflating: icadar_1000/img_508.jpg
#   inflating: icadar_1000/img_509.jpg
#   inflating: icadar_1000/img_510.jpg
#   inflating: icadar_1000/img_511.jpg
#   inflating: icadar_1000/img_512.jpg
#   inflating: icadar_1000/img_513.jpg
#   inflating: icadar_1000/img_514.jpg
#   inflating: icadar_1000/img_515.jpg
#   inflating: icadar_1000/img_516.jpg
#   inflating: icadar_1000/img_517.jpg
#   inflating: icadar_1000/img_518.jpg
#   inflating: icadar_1000/img_519.jpg
#   inflating: icadar_1000/img_520.jpg
#   inflating: icadar_1000/img_521.jpg
#   inflating: icadar_1000/img_522.jpg
#   inflating: icadar_1000/img_523.jpg
#   inflating: icadar_1000/img_524.jpg
#   inflating: icadar_1000/img_525.jpg
#   inflating: icadar_1000/img_526.jpg
#   inflating: icadar_1000/img_527.jpg
#   inflating: icadar_1000/img_528.jpg
#   inflating: icadar_1000/img_529.jpg
#   inflating: icadar_1000/img_530.jpg
#   inflating: icadar_1000/img_531.jpg
#   inflating: icadar_1000/img_532.jpg
#   inflating: icadar_1000/img_533.jpg
#   inflating: icadar_1000/img_534.jpg
#   inflating: icadar_1000/img_535.jpg
#   inflating: icadar_1000/img_536.jpg
#   inflating: icadar_1000/img_537.jpg
#   inflating: icadar_1000/img_538.jpg
#   inflating: icadar_1000/img_539.jpg
#   inflating: icadar_1000/img_540.jpg
#   inflating: icadar_1000/img_541.jpg
#   inflating: icadar_1000/img_542.jpg
#   inflating: icadar_1000/img_543.jpg
#   inflating: icadar_1000/img_544.jpg
#   inflating: icadar_1000/img_545.jpg
#   inflating: icadar_1000/img_546.jpg
#   inflating: icadar_1000/img_547.jpg
#   inflating: icadar_1000/img_548.jpg
#   inflating: icadar_1000/img_549.jpg
#   inflating: icadar_1000/img_550.jpg
#   inflating: icadar_1000/img_551.jpg
#   inflating: icadar_1000/img_552.jpg
#   inflating: icadar_1000/img_553.jpg
#   inflating: icadar_1000/img_554.jpg
#   inflating: icadar_1000/img_555.jpg
#   inflating: icadar_1000/img_556.jpg
#   inflating: icadar_1000/img_557.jpg
#   inflating: icadar_1000/img_558.jpg
#   inflating: icadar_1000/img_559.jpg
#   inflating: icadar_1000/img_560.jpg
#   inflating: icadar_1000/img_561.jpg
#   inflating: icadar_1000/img_562.jpg
#   inflating: icadar_1000/img_563.jpg
#   inflating: icadar_1000/img_564.jpg
#   inflating: icadar_1000/img_565.jpg
#   inflating: icadar_1000/img_566.jpg
#   inflating: icadar_1000/img_567.jpg
#   inflating: icadar_1000/img_568.jpg
#   inflating: icadar_1000/img_569.jpg
#   inflating: icadar_1000/img_570.jpg
#   inflating: icadar_1000/img_571.jpg
#   inflating: icadar_1000/img_572.jpg
#   inflating: icadar_1000/img_573.jpg
#   inflating: icadar_1000/img_574.jpg
#   inflating: icadar_1000/img_575.jpg
#   inflating: icadar_1000/img_576.jpg
#   inflating: icadar_1000/img_577.jpg
#   inflating: icadar_1000/img_578.jpg
#   inflating: icadar_1000/img_579.jpg
#   inflating: icadar_1000/img_580.jpg
#   inflating: icadar_1000/img_581.jpg
#   inflating: icadar_1000/img_582.jpg
#   inflating: icadar_1000/img_583.jpg
#   inflating: icadar_1000/img_584.jpg
#   inflating: icadar_1000/img_585.jpg
#   inflating: icadar_1000/img_586.jpg
#   inflating: icadar_1000/img_587.jpg
#   inflating: icadar_1000/img_588.jpg
#   inflating: icadar_1000/img_589.jpg
#   inflating: icadar_1000/img_590.jpg
#   inflating: icadar_1000/img_591.jpg
#   inflating: icadar_1000/img_592.jpg
#   inflating: icadar_1000/img_593.jpg
#   inflating: icadar_1000/img_594.jpg
#   inflating: icadar_1000/img_595.jpg
#   inflating: icadar_1000/img_596.jpg
#   inflating: icadar_1000/img_597.jpg
#   inflating: icadar_1000/img_598.jpg
#   inflating: icadar_1000/img_599.jpg
#   inflating: icadar_1000/img_600.jpg
#   inflating: icadar_1000/img_601.jpg
#   inflating: icadar_1000/img_602.jpg
#   inflating: icadar_1000/img_603.jpg
#   inflating: icadar_1000/img_604.jpg
#   inflating: icadar_1000/img_605.jpg
#   inflating: icadar_1000/img_606.jpg
#   inflating: icadar_1000/img_607.jpg
#   inflating: icadar_1000/img_608.jpg
#   inflating: icadar_1000/img_609.jpg
#   inflating: icadar_1000/img_610.jpg
#   inflating: icadar_1000/img_611.jpg
#   inflating: icadar_1000/img_612.jpg
#   inflating: icadar_1000/img_613.jpg
#   inflating: icadar_1000/img_614.jpg
#   inflating: icadar_1000/img_615.jpg
#   inflating: icadar_1000/img_616.jpg
#   inflating: icadar_1000/img_617.jpg
#   inflating: icadar_1000/img_618.jpg
#   inflating: icadar_1000/img_619.jpg
#   inflating: icadar_1000/img_620.jpg
#   inflating: icadar_1000/img_621.jpg
#   inflating: icadar_1000/img_622.jpg
#   inflating: icadar_1000/img_623.jpg
#   inflating: icadar_1000/img_624.jpg
#   inflating: icadar_1000/img_625.jpg
#   inflating: icadar_1000/img_626.jpg
#   inflating: icadar_1000/img_627.jpg
#   inflating: icadar_1000/img_628.jpg
#   inflating: icadar_1000/img_629.jpg
#   inflating: icadar_1000/img_630.jpg
#   inflating: icadar_1000/img_631.jpg
#   inflating: icadar_1000/img_632.jpg
#   inflating: icadar_1000/img_633.jpg
#   inflating: icadar_1000/img_634.jpg
#   inflating: icadar_1000/img_635.jpg
#   inflating: icadar_1000/img_636.jpg
#   inflating: icadar_1000/img_637.jpg
#   inflating: icadar_1000/img_638.jpg
#   inflating: icadar_1000/img_639.jpg
#   inflating: icadar_1000/img_640.jpg
#   inflating: icadar_1000/img_641.jpg
#   inflating: icadar_1000/img_642.jpg
#   inflating: icadar_1000/img_643.jpg
#   inflating: icadar_1000/img_644.jpg
#   inflating: icadar_1000/img_645.jpg
#   inflating: icadar_1000/img_646.jpg
#   inflating: icadar_1000/img_647.jpg
#   inflating: icadar_1000/img_648.jpg
#   inflating: icadar_1000/img_649.jpg
#   inflating: icadar_1000/img_650.jpg
#   inflating: icadar_1000/img_651.jpg
#   inflating: icadar_1000/img_652.jpg
#   inflating: icadar_1000/img_653.jpg
#   inflating: icadar_1000/img_654.jpg
#   inflating: icadar_1000/img_655.jpg
#   inflating: icadar_1000/img_656.jpg
#   inflating: icadar_1000/img_657.jpg
#   inflating: icadar_1000/img_658.jpg
#   inflating: icadar_1000/img_659.jpg
#   inflating: icadar_1000/img_660.jpg
#   inflating: icadar_1000/img_661.jpg
#   inflating: icadar_1000/img_662.jpg
#   inflating: icadar_1000/img_663.jpg
#   inflating: icadar_1000/img_664.jpg
#   inflating: icadar_1000/img_665.jpg
#   inflating: icadar_1000/img_666.jpg
#   inflating: icadar_1000/img_667.jpg
#   inflating: icadar_1000/img_668.jpg
#   inflating: icadar_1000/img_669.jpg
#   inflating: icadar_1000/img_670.jpg
#   inflating: icadar_1000/img_671.jpg
#   inflating: icadar_1000/img_672.jpg
#   inflating: icadar_1000/img_673.jpg
#   inflating: icadar_1000/img_674.jpg
#   inflating: icadar_1000/img_675.jpg
#   inflating: icadar_1000/img_676.jpg
#   inflating: icadar_1000/img_677.jpg
#   inflating: icadar_1000/img_678.jpg
#   inflating: icadar_1000/img_679.jpg
#   inflating: icadar_1000/img_680.jpg
#   inflating: icadar_1000/img_681.jpg
#   inflating: icadar_1000/img_682.jpg
#   inflating: icadar_1000/img_683.jpg
#   inflating: icadar_1000/img_684.jpg
#   inflating: icadar_1000/img_685.jpg
#   inflating: icadar_1000/img_686.jpg
#   inflating: icadar_1000/img_687.jpg
#   inflating: icadar_1000/img_688.jpg
#   inflating: icadar_1000/img_689.jpg
#   inflating: icadar_1000/img_690.jpg
#   inflating: icadar_1000/img_691.jpg
#   inflating: icadar_1000/img_692.jpg
#   inflating: icadar_1000/img_693.jpg
#   inflating: icadar_1000/img_694.jpg
#   inflating: icadar_1000/img_695.jpg
#   inflating: icadar_1000/img_696.jpg
#   inflating: icadar_1000/img_697.jpg
#   inflating: icadar_1000/img_698.jpg
#   inflating: icadar_1000/img_699.jpg
#   inflating: icadar_1000/img_700.jpg
#   inflating: icadar_1000/img_701.jpg
#   inflating: icadar_1000/img_702.jpg
#   inflating: icadar_1000/img_703.jpg
#   inflating: icadar_1000/img_704.jpg
#   inflating: icadar_1000/img_705.jpg
#   inflating: icadar_1000/img_706.jpg
#   inflating: icadar_1000/img_707.jpg
#   inflating: icadar_1000/img_708.jpg
#   inflating: icadar_1000/img_709.jpg
#   inflating: icadar_1000/img_710.jpg
#   inflating: icadar_1000/img_711.jpg
#   inflating: icadar_1000/img_712.jpg
#   inflating: icadar_1000/img_713.jpg
#   inflating: icadar_1000/img_714.jpg
#   inflating: icadar_1000/img_715.jpg
#   inflating: icadar_1000/img_716.jpg
#   inflating: icadar_1000/img_717.jpg
#   inflating: icadar_1000/img_718.jpg
#   inflating: icadar_1000/img_719.jpg
#   inflating: icadar_1000/img_720.jpg
#   inflating: icadar_1000/img_721.jpg
#   inflating: icadar_1000/img_722.jpg
#   inflating: icadar_1000/img_723.jpg
#   inflating: icadar_1000/img_724.jpg
#   inflating: icadar_1000/img_725.jpg
#   inflating: icadar_1000/img_726.jpg
#   inflating: icadar_1000/img_727.jpg
#   inflating: icadar_1000/img_728.jpg
#   inflating: icadar_1000/img_729.jpg
#   inflating: icadar_1000/img_730.jpg
#   inflating: icadar_1000/img_731.jpg
#   inflating: icadar_1000/img_732.jpg
#   inflating: icadar_1000/img_733.jpg
#   inflating: icadar_1000/img_734.jpg
#   inflating: icadar_1000/img_735.jpg
#   inflating: icadar_1000/img_736.jpg
#   inflating: icadar_1000/img_737.jpg
#   inflating: icadar_1000/img_738.jpg
#   inflating: icadar_1000/img_739.jpg
#   inflating: icadar_1000/img_740.jpg
#   inflating: icadar_1000/img_741.jpg
#   inflating: icadar_1000/img_742.jpg
#   inflating: icadar_1000/img_743.jpg
#   inflating: icadar_1000/img_744.jpg
#   inflating: icadar_1000/img_745.jpg
#   inflating: icadar_1000/img_746.jpg
#   inflating: icadar_1000/img_747.jpg
#   inflating: icadar_1000/img_748.jpg
#   inflating: icadar_1000/img_749.jpg
#   inflating: icadar_1000/img_750.jpg
#   inflating: icadar_1000/img_751.jpg
#   inflating: icadar_1000/img_752.jpg
#   inflating: icadar_1000/img_753.jpg
#   inflating: icadar_1000/img_754.jpg
#   inflating: icadar_1000/img_755.jpg
#   inflating: icadar_1000/img_756.jpg
#   inflating: icadar_1000/img_757.jpg
#   inflating: icadar_1000/img_758.jpg
#   inflating: icadar_1000/img_759.jpg
#   inflating: icadar_1000/img_760.jpg
#   inflating: icadar_1000/img_761.jpg
#   inflating: icadar_1000/img_762.jpg
#   inflating: icadar_1000/img_763.jpg
#   inflating: icadar_1000/img_764.jpg
#   inflating: icadar_1000/img_765.jpg
#   inflating: icadar_1000/img_766.jpg
#   inflating: icadar_1000/img_767.jpg
#   inflating: icadar_1000/img_768.jpg
#   inflating: icadar_1000/img_769.jpg
#   inflating: icadar_1000/img_770.jpg
#   inflating: icadar_1000/img_771.jpg
#   inflating: icadar_1000/img_772.jpg
#   inflating: icadar_1000/img_773.jpg
#   inflating: icadar_1000/img_774.jpg
#   inflating: icadar_1000/img_775.jpg
#   inflating: icadar_1000/img_776.jpg
#   inflating: icadar_1000/img_777.jpg
#   inflating: icadar_1000/img_778.jpg
#   inflating: icadar_1000/img_779.jpg
#   inflating: icadar_1000/img_780.jpg
#   inflating: icadar_1000/img_781.jpg
#   inflating: icadar_1000/img_782.jpg
#   inflating: icadar_1000/img_783.jpg
#   inflating: icadar_1000/img_784.jpg
#   inflating: icadar_1000/img_785.jpg
#   inflating: icadar_1000/img_786.jpg
#   inflating: icadar_1000/img_787.jpg
#   inflating: icadar_1000/img_788.jpg
#   inflating: icadar_1000/img_789.jpg
#   inflating: icadar_1000/img_790.jpg
#   inflating: icadar_1000/img_791.jpg
#   inflating: icadar_1000/img_792.jpg
#   inflating: icadar_1000/img_793.jpg
#   inflating: icadar_1000/img_794.jpg
#   inflating: icadar_1000/img_795.jpg
#   inflating: icadar_1000/img_796.jpg
#   inflating: icadar_1000/img_797.jpg
#   inflating: icadar_1000/img_798.jpg
#   inflating: icadar_1000/img_799.jpg
#   inflating: icadar_1000/img_800.jpg
#   inflating: icadar_1000/img_801.jpg
#   inflating: icadar_1000/img_802.jpg
#   inflating: icadar_1000/img_803.jpg
#   inflating: icadar_1000/img_804.jpg
#   inflating: icadar_1000/img_805.jpg
#   inflating: icadar_1000/img_806.jpg
#   inflating: icadar_1000/img_807.jpg
#   inflating: icadar_1000/img_808.jpg
#   inflating: icadar_1000/img_809.jpg
#   inflating: icadar_1000/img_810.jpg
#   inflating: icadar_1000/img_811.jpg
#   inflating: icadar_1000/img_812.jpg
#   inflating: icadar_1000/img_813.jpg
#   inflating: icadar_1000/img_814.jpg
#   inflating: icadar_1000/img_815.jpg
#   inflating: icadar_1000/img_816.jpg
#   inflating: icadar_1000/img_817.jpg
#   inflating: icadar_1000/img_818.jpg
#   inflating: icadar_1000/img_819.jpg
#   inflating: icadar_1000/img_820.jpg
#   inflating: icadar_1000/img_821.jpg
#   inflating: icadar_1000/img_822.jpg
#   inflating: icadar_1000/img_823.jpg
#   inflating: icadar_1000/img_824.jpg
#   inflating: icadar_1000/img_825.jpg
#   inflating: icadar_1000/img_826.jpg
#   inflating: icadar_1000/img_827.jpg
#   inflating: icadar_1000/img_828.jpg
#   inflating: icadar_1000/img_829.jpg
#   inflating: icadar_1000/img_830.jpg
#   inflating: icadar_1000/img_831.jpg
#   inflating: icadar_1000/img_832.jpg
#   inflating: icadar_1000/img_833.jpg
#   inflating: icadar_1000/img_834.jpg
#   inflating: icadar_1000/img_835.jpg
#   inflating: icadar_1000/img_836.jpg
#   inflating: icadar_1000/img_837.jpg
#   inflating: icadar_1000/img_838.jpg
#   inflating: icadar_1000/img_839.jpg
#   inflating: icadar_1000/img_840.jpg
#   inflating: icadar_1000/img_841.jpg
#   inflating: icadar_1000/img_842.jpg
#   inflating: icadar_1000/img_843.jpg
#   inflating: icadar_1000/img_844.jpg
#   inflating: icadar_1000/img_845.jpg
#   inflating: icadar_1000/img_846.jpg
#   inflating: icadar_1000/img_847.jpg
#   inflating: icadar_1000/img_848.jpg
#   inflating: icadar_1000/img_849.jpg
#   inflating: icadar_1000/img_850.jpg
#   inflating: icadar_1000/img_851.jpg
#   inflating: icadar_1000/img_852.jpg
#   inflating: icadar_1000/img_853.jpg
#   inflating: icadar_1000/img_854.jpg
#   inflating: icadar_1000/img_855.jpg
#   inflating: icadar_1000/img_856.jpg
#   inflating: icadar_1000/img_857.jpg
#   inflating: icadar_1000/img_858.jpg
#   inflating: icadar_1000/img_859.jpg
#   inflating: icadar_1000/img_860.jpg
#   inflating: icadar_1000/img_861.jpg
#   inflating: icadar_1000/img_862.jpg
#   inflating: icadar_1000/img_863.jpg
#   inflating: icadar_1000/img_864.jpg
#   inflating: icadar_1000/img_865.jpg
#   inflating: icadar_1000/img_866.jpg
#   inflating: icadar_1000/img_867.jpg
#   inflating: icadar_1000/img_868.jpg
#   inflating: icadar_1000/img_869.jpg
#   inflating: icadar_1000/img_870.jpg
#   inflating: icadar_1000/img_871.jpg
#   inflating: icadar_1000/img_872.jpg
#   inflating: icadar_1000/img_873.jpg
#   inflating: icadar_1000/img_874.jpg
#   inflating: icadar_1000/img_875.jpg
#   inflating: icadar_1000/img_876.jpg
#   inflating: icadar_1000/img_877.jpg
#   inflating: icadar_1000/img_878.jpg
#   inflating: icadar_1000/img_879.jpg
#   inflating: icadar_1000/img_880.jpg
#   inflating: icadar_1000/img_881.jpg
#   inflating: icadar_1000/img_882.jpg
#   inflating: icadar_1000/img_883.jpg
#   inflating: icadar_1000/img_884.jpg
#   inflating: icadar_1000/img_885.jpg
#   inflating: icadar_1000/img_886.jpg
#   inflating: icadar_1000/img_887.jpg
#   inflating: icadar_1000/img_888.jpg
#   inflating: icadar_1000/img_889.jpg
#   inflating: icadar_1000/img_890.jpg
#   inflating: icadar_1000/img_891.jpg
#   inflating: icadar_1000/img_892.jpg
#   inflating: icadar_1000/img_893.jpg
#   inflating: icadar_1000/img_894.jpg
#   inflating: icadar_1000/img_895.jpg
#   inflating: icadar_1000/img_896.jpg
#   inflating: icadar_1000/img_897.jpg
#   inflating: icadar_1000/img_898.jpg
#   inflating: icadar_1000/img_899.jpg
#   inflating: icadar_1000/img_900.jpg
#   inflating: icadar_1000/img_901.jpg
#   inflating: icadar_1000/img_902.jpg
#   inflating: icadar_1000/img_903.jpg
#   inflating: icadar_1000/img_904.jpg
#   inflating: icadar_1000/img_905.jpg
#   inflating: icadar_1000/img_906.jpg
#   inflating: icadar_1000/img_907.jpg
#   inflating: icadar_1000/img_908.jpg
#   inflating: icadar_1000/img_909.jpg
#   inflating: icadar_1000/img_910.jpg
#   inflating: icadar_1000/img_911.jpg
#   inflating: icadar_1000/img_912.jpg
#   inflating: icadar_1000/img_913.jpg
#   inflating: icadar_1000/img_914.jpg
#   inflating: icadar_1000/img_915.jpg
#   inflating: icadar_1000/img_916.jpg
#   inflating: icadar_1000/img_917.jpg
#   inflating: icadar_1000/img_918.jpg
#   inflating: icadar_1000/img_919.jpg
#   inflating: icadar_1000/img_920.jpg
#   inflating: icadar_1000/img_921.jpg
#   inflating: icadar_1000/img_922.jpg
#   inflating: icadar_1000/img_923.jpg
#   inflating: icadar_1000/img_924.jpg
#   inflating: icadar_1000/img_925.jpg
#   inflating: icadar_1000/img_926.jpg
#   inflating: icadar_1000/img_927.jpg
#   inflating: icadar_1000/img_928.jpg
#   inflating: icadar_1000/img_929.jpg
#   inflating: icadar_1000/img_930.jpg
#   inflating: icadar_1000/img_931.jpg
#   inflating: icadar_1000/img_932.jpg
#   inflating: icadar_1000/img_933.jpg
#   inflating: icadar_1000/img_934.jpg
#   inflating: icadar_1000/img_935.jpg
#   inflating: icadar_1000/img_936.jpg
#   inflating: icadar_1000/img_937.jpg
#   inflating: icadar_1000/img_938.jpg
#   inflating: icadar_1000/img_939.jpg
#   inflating: icadar_1000/img_940.jpg
#   inflating: icadar_1000/img_941.jpg
#   inflating: icadar_1000/img_942.jpg
#   inflating: icadar_1000/img_943.jpg
#   inflating: icadar_1000/img_944.jpg
#   inflating: icadar_1000/img_945.jpg
#   inflating: icadar_1000/img_946.jpg
#   inflating: icadar_1000/img_947.jpg
#   inflating: icadar_1000/img_948.jpg
#   inflating: icadar_1000/img_949.jpg
#   inflating: icadar_1000/img_950.jpg
#   inflating: icadar_1000/img_951.jpg
#   inflating: icadar_1000/img_952.jpg
#   inflating: icadar_1000/img_953.jpg
#   inflating: icadar_1000/img_954.jpg
#   inflating: icadar_1000/img_955.jpg
#   inflating: icadar_1000/img_956.jpg
#   inflating: icadar_1000/img_957.jpg
#   inflating: icadar_1000/img_958.jpg
#   inflating: icadar_1000/img_959.jpg
#   inflating: icadar_1000/img_960.jpg
#   inflating: icadar_1000/img_961.jpg
#   inflating: icadar_1000/img_962.jpg
#   inflating: icadar_1000/img_963.jpg
#   inflating: icadar_1000/img_964.jpg
#   inflating: icadar_1000/img_965.jpg
#   inflating: icadar_1000/img_966.jpg
#   inflating: icadar_1000/img_967.jpg
#   inflating: icadar_1000/img_968.jpg
#   inflating: icadar_1000/img_969.jpg
#   inflating: icadar_1000/img_970.jpg
#   inflating: icadar_1000/img_971.jpg
#   inflating: icadar_1000/img_972.jpg
#   inflating: icadar_1000/img_973.jpg
#   inflating: icadar_1000/img_974.jpg
#   inflating: icadar_1000/img_975.jpg
#   inflating: icadar_1000/img_976.jpg
#   inflating: icadar_1000/img_977.jpg
#   inflating: icadar_1000/img_978.jpg
#   inflating: icadar_1000/img_979.jpg
#   inflating: icadar_1000/img_980.jpg
#   inflating: icadar_1000/img_981.jpg
#   inflating: icadar_1000/img_982.jpg
#   inflating: icadar_1000/img_983.jpg
#   inflating: icadar_1000/img_984.jpg
#   inflating: icadar_1000/img_985.jpg
#   inflating: icadar_1000/img_986.jpg
#   inflating: icadar_1000/img_987.jpg
#   inflating: icadar_1000/img_988.jpg
#   inflating: icadar_1000/img_989.jpg
#   inflating: icadar_1000/img_990.jpg
#   inflating: icadar_1000/img_991.jpg
#   inflating: icadar_1000/img_992.jpg
#   inflating: icadar_1000/img_993.jpg
#   inflating: icadar_1000/img_994.jpg
#   inflating: icadar_1000/img_995.jpg
#   inflating: icadar_1000/img_996.jpg
#   inflating: icadar_1000/img_997.jpg
#   inflating: icadar_1000/img_998.jpg
#   inflating: icadar_1000/img_999.jpg
#   inflating: icadar_1000/img_1000.jpg

# %%
def get_all_file_paths(directory):
  
    # initializing empty file paths list
    file_paths = []
  
    # crawling through directory and subdirectories
    for root, directories, files in os.walk(directory):
        for filename in files:
            # join the two strings in order to form the full filepath.
            filepath = os.path.join(root, filename)
            file_paths.append(filepath)
  
    # returning all file paths
    file_paths = random.sample(file_paths, 5)
    return file_paths          
directory = '/content/icadar_1000'  
path = get_all_file_paths(directory)

# %%
def show_image(path):
    img=cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    im,txt=Final_Pipeline(img)
    ax=plt.figure(figsize=(8,8))
    plt.title(','.join(txt),fontsize=20)
    plt.imshow(im)
    
for i in path:
  show_image(i)
# Out:
# Time Taken By Pipeline=6.6901328563690186 seconds
# Time Taken By Pipeline=1.6198148727416992 seconds
# Time Taken By Pipeline=1.6785776615142822 seconds
# Time Taken By Pipeline=2.2283785343170166 seconds
# Time Taken By Pipeline=1.7075984477996826 seconds

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. we can see that detection model is still doing fine but recognition model is not performing that good.
# 2. This is because We have only taken only 15k images from 800k images form synthtext for detection and 10k images for recognition, we have not trained our  models on the whole data of synthtext as it is  41GB huge which requires high computation power and because of less computation power and resources use that much of data.
# 3. Both detection and recognition models can be trained on more data to provide with better results

# %% [markdown]
# # Future Work

# %% [markdown]
# 1. Will be making use of full synthtext data for training both the parts of detection and recgnition
# 2. Working on detection part to produce more accurate bounding boxes
# 3. Organizing the code in more readable form
# 4. Could Use NLP method laye to decode the word properly in recognition layer
